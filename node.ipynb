# %%
import torch

from neural_ode.core import set_seed, NeuralODEClassifier
from neural_ode.experiments import run_experiment
from neural_ode.plots import plot_experiment_report

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
set_seed(42)

model_200 = NeuralODEClassifier(
    latent_dim=2,
    hidden_dim=96,
    encoder_type="parabola",
    integration_end=2.0,
    decoder_mlp=True,
)

result_200 = run_experiment(
    model=model_200,
    train_size=200,
    val_size=4000,
    test_size=10000,
    model_name="200 training points",
    epochs=120,
    batch_size=1024,
    lr=3e-3,
    weight_decay=1e-5,
    grad_clip_norm=1.0,
    use_cosine_scheduler=True,
    device=device,
)

plot_experiment_report(result_200, device=device, latent_trajectory_points=17)
# Out:
# ================================================================================
# Training set size: 200
# Epoch   1 | train loss 2.3347 acc 0.1050 | val loss 2.3222 acc 0.1485
# Epoch  10 | train loss 2.1119 acc 0.2000 | val loss 2.0981 acc 0.1985
# Epoch  20 | train loss 1.5112 acc 0.2600 | val loss 1.5616 acc 0.2693
# Epoch  30 | train loss 1.3160 acc 0.3650 | val loss 1.3370 acc 0.3695
# Epoch  40 | train loss 1.0586 acc 0.6550 | val loss 1.0473 acc 0.6165
# Epoch  50 | train loss 0.7766 acc 0.7400 | val loss 0.7914 acc 0.7322
# Epoch  60 | train loss 0.5985 acc 0.8150 | val loss 0.6088 acc 0.8090
# Epoch  70 | train loss 0.5515 acc 0.7300 | val loss 0.5093 acc 0.7782
# Epoch  80 | train loss 0.3997 acc 0.9200 | val loss 0.4255 acc 0.8867
# Epoch  90 | train loss 0.3593 acc 0.9050 | val loss 0.3877 acc 0.8845
# Epoch 100 | train loss 0.3387 acc 0.9050 | val loss 0.3611 acc 0.9125
# Epoch 110 | train loss 0.3223 acc 0.9000 | val loss 0.3453 acc 0.9168
# Epoch 120 | train loss 0.3181 acc 0.9200 | val loss 0.3419 acc 0.9160
# Restored best validation checkpoint from epoch 111.
# [200 training points] test loss = 0.3336, test acc = 0.9213

# %%
set_seed(42)

model_2000 = NeuralODEClassifier(
    latent_dim=2,
    hidden_dim=96,
    encoder_type="parabola",
    integration_end=2.0,
    decoder_mlp=True,
)

result_2000 = run_experiment(
    model=model_2000,
    train_size=2000,
    val_size=4000,
    test_size=10000,
    model_name="2000 training points",
    epochs=120,
    batch_size=1024,
    lr=3e-3,
    weight_decay=1e-5,
    grad_clip_norm=1.0,
    use_cosine_scheduler=True,
    device=device,
)

plot_experiment_report(result_2000, device=device, latent_trajectory_points=17)
# Out:
# ================================================================================
# Training set size: 2000
# Epoch   1 | train loss 2.3246 acc 0.1050 | val loss 2.3001 acc 0.1335
# Epoch  10 | train loss 1.6164 acc 0.1660 | val loss 1.5818 acc 0.2055
# Epoch  20 | train loss 1.1788 acc 0.4920 | val loss 1.1390 acc 0.5748
# Epoch  30 | train loss 0.7896 acc 0.7590 | val loss 0.7639 acc 0.8110
# Epoch  40 | train loss 0.5762 acc 0.8100 | val loss 0.5921 acc 0.7580
# Epoch  50 | train loss 0.5092 acc 0.7870 | val loss 0.4693 acc 0.8680
# Epoch  60 | train loss 0.4030 acc 0.8805 | val loss 0.4351 acc 0.8322
# Epoch  70 | train loss 0.3558 acc 0.8835 | val loss 0.3494 acc 0.9015
# Epoch  80 | train loss 0.3166 acc 0.9165 | val loss 0.3108 acc 0.9225
# Epoch  90 | train loss 0.2679 acc 0.9250 | val loss 0.2752 acc 0.9130
# Epoch 100 | train loss 0.2425 acc 0.9330 | val loss 0.2505 acc 0.9218
# Epoch 110 | train loss 0.2291 acc 0.9325 | val loss 0.2391 acc 0.9230
# Epoch 120 | train loss 0.2257 acc 0.9350 | val loss 0.2366 acc 0.9247
# Restored best validation checkpoint from epoch 119.
# [2000 training points] test loss = 0.2256, test acc = 0.9332

# %%
set_seed(42)

model_20000 = NeuralODEClassifier(
    latent_dim=2,
    hidden_dim=96,
    encoder_type="parabola",
    integration_end=2.0,
    decoder_mlp=True,
)

result_20000 = run_experiment(
    model=model_20000,
    train_size=20000,
    val_size=4000,
    test_size=10000,
    model_name="20 000 training points",
    epochs=120,
    batch_size=1024,
    lr=3e-3,
    weight_decay=1e-5,
    grad_clip_norm=1.0,
    use_cosine_scheduler=True,
    device=device,
)

plot_experiment_report(result_20000, device=device, latent_trajectory_points=17)
# Out:
# ================================================================================
# Training set size: 20000
# Epoch   1 | train loss 2.0238 acc 0.1831 | val loss 1.6360 acc 0.2192
# Epoch  10 | train loss 0.4174 acc 0.7850 | val loss 0.3230 acc 0.8680
# Epoch  20 | train loss 0.2490 acc 0.8922 | val loss 0.2130 acc 0.9057
# Epoch  30 | train loss 0.2016 acc 0.9103 | val loss 0.1572 acc 0.9388
# Epoch  40 | train loss 0.2208 acc 0.9118 | val loss 0.2305 acc 0.9015
# Epoch  50 | train loss 0.2523 acc 0.8884 | val loss 0.1577 acc 0.9323
# Epoch  60 | train loss 0.1763 acc 0.9206 | val loss 0.2181 acc 0.8997
# Epoch  70 | train loss 0.1334 acc 0.9425 | val loss 0.1378 acc 0.9398
# Epoch  80 | train loss 0.1647 acc 0.9301 | val loss 0.1285 acc 0.9438
# Epoch  90 | train loss 0.1193 acc 0.9436 | val loss 0.1174 acc 0.9450
# Epoch 100 | train loss 0.1112 acc 0.9501 | val loss 0.1082 acc 0.9517
# Epoch 110 | train loss 0.0985 acc 0.9593 | val loss 0.0917 acc 0.9645
# Epoch 120 | train loss 0.0926 acc 0.9631 | val loss 0.0882 acc 0.9657
# Restored best validation checkpoint from epoch 62.
# [20 000 training points] test loss = 0.1201, test acc = 0.9668
